# %% [markdown]
# # 1.6 Building Protein Systems in Explicit Water
# https://ambermd.org/tutorials/basic/tutorial7/index.php

# %%
import os

# %%
os.chdir('B2')

# %%
# !tleap
# Out:
# -I: Adding /home/wjoon21/anaconda3/envs/ppis/dat/leap/prep to search path.
# -I: Adding /home/wjoon21/anaconda3/envs/ppis/dat/leap/lib to search path.
# -I: Adding /home/wjoon21/anaconda3/envs/ppis/dat/leap/parm to search path.
# -I: Adding /home/wjoon21/anaconda3/envs/ppis/dat/leap/cmd to search path.
#
# Welcome to LEaP!
# (no leaprc in search path)
# >

# %%
# !source leaprc.protein.ff19SB
# Out:
# /bin/bash: leaprc.protein.ff19SB: No such file or directory

# %% [markdown]
# Micro-shell cannot be used to run MD continuously...
#
# Use terminal in VS Code

# %% [markdown]
# ## Trial 1
# WRONG
# 1. did NOT neutralize protein
# 2. NEED step explanations

# %% [markdown]
# ### III. Evaluate and Analyze the Protein Structure to be Imported into Amber

# %% [markdown]
# Missing residues, residue/atom name conversion etc. processing has been done wtih `pdb4amber` in `01_interface_visualisation.ipynb`

# %% [markdown]
# ```sh
# wjoon21@puma:~/project/chen2023_possible_allosteric/B2$ tleap
# -I: Adding /home/t38guest/amber22/dat/leap/prep to search path.
# -I: Adding /home/t38guest/amber22/dat/leap/lib to search path.
# -I: Adding /home/t38guest/amber22/dat/leap/parm to search path.
# -I: Adding /home/t38guest/amber22/dat/leap/cmd to search path.
#
# Welcome to LEaP!
# (no leaprc in search path)
# ```

# %% [markdown]
# ```tleap
# > source leaprc.protein.ff19SB
# ----- Source: /home/t38guest/amber22/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/t38guest/amber22/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/t38guest/amber22/dat/leap/lib/amino19.lib
# Loading library: /home/t38guest/amber22/dat/leap/lib/aminoct12.lib
# Loading library: /home/t38guest/amber22/dat/leap/lib/aminont12.lib
# ```

# %% [markdown]
# ```tleap
# > source leaprc.water.opc
# ----- Source: /home/t38guest/amber22/dat/leap/cmd/leaprc.water.opc
# ----- Source of /home/t38guest/amber22/dat/leap/cmd/leaprc.water.opc done
# Loading library: /home/t38guest/amber22/dat/leap/lib/atomic_ions.lib
# Loading library: /home/t38guest/amber22/dat/leap/lib/solvents.lib
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/frcmod.opc
# Reading force field modification type file (frcmod)
# Reading title:
# Parameters for OPC water (JPCL, 2014, 5 (21), pp 3863-3871)
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/frcmod.ionslm_126_opc
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of atomic ions for the OPC water model (12-6 set)
# ```

# %% [markdown]
# ```tleap
# > ramp=loadpdb amber_o98.B99990002.pdb
# Loading PDB file: ./amber_o98.B99990002.pdb
#   total atoms in file: 2348
#   Leap added 2340 missing atoms according to residue templates:
#        2340 H / lone pairs
# ```

# %% [markdown]
# ```tleap
# >solvateOct ramp OPCBOX 10.0
# Scaling up box by a factor of 1.381491 to meet diagonal cut criterion
#   Solute vdw bounding box:              71.159 63.750 54.439
#   Total bounding box for atom centers:  98.789 98.789 98.789
#       (box expansion for 'iso' is  30.1%)
#   Solvent unit box:                     18.865 18.478 19.006
#   Volume: 496844.236 A^3 (oct)
#   Total mass 267734.056 amu,  Density 0.895 g/cc
#   Added 13006 residues.
# ```

# %%
volumeOctBoxAngstrom = 496844.236

# %%
volumeOctBoxLiter = 496844.236 * 1/(10**10)**3 * (10**2)**3/1 * 1/1 * 1/10**3
volumeOctBoxLiter
# Out:
# 4.96844236e-22

# %%
numberClperLiter = 150/1 * 1/10**3 * (6.022*10**23)/1
numberClperLiter
# Out:
# 9.033e+22

# %%
numberClOctBox = 4.96844236e-22 * 9.033e+22
numberClOctBox
# Out:
# 44.87993983788

# %% [markdown]
# ```tleap
# > addIonsRand ramp Na+ 45 Cl- 45
# Adding 90 counter ions to "ramp". 12916 solvent molecules will remain.
# 0: Placed Na+ in ramp at (12.04, 33.68, 14.53).
# Placed Cl- in ramp at (0.82, 2.77, 45.21).
# 0: Placed Na+ in ramp at (13.42, 31.23, 1.42).
# Placed Cl- in ramp at (20.62, 24.53, -15.21).
# 0: Placed Na+ in ramp at (29.94, -14.32, 16.88).
# Placed Cl- in ramp at (40.39, -10.61, -12.10).
# 0: Placed Na+ in ramp at (-37.86, 14.90, 3.90).
# Placed Cl- in ramp at (-27.96, -14.81, 0.53).
# 0: Placed Na+ in ramp at (-15.90, -27.55, 5.75).
# Placed Cl- in ramp at (-19.06, 35.47, -14.13).
# 0: Placed Na+ in ramp at (25.16, 23.85, -6.18).
# Placed Cl- in ramp at (16.22, -11.39, -47.08).
# 0: Placed Na+ in ramp at (17.57, 13.08, -16.39).
# Placed Cl- in ramp at (-17.21, 21.86, -30.90).
# 0: Placed Na+ in ramp at (-16.88, 36.62, 13.57).
# Placed Cl- in ramp at (-7.96, -7.70, -21.59).
# 0: Placed Na+ in ramp at (-12.88, -46.99, 0.02).
# Placed Cl- in ramp at (41.02, -3.37, -17.77).
# 0: Placed Na+ in ramp at (-27.06, 4.80, 7.73).
# Placed Cl- in ramp at (33.53, -7.66, -3.92).
# 0: Placed Na+ in ramp at (-12.98, -44.28, -8.13).
# Placed Cl- in ramp at (-6.24, 21.65, -34.29).
# 0: Placed Na+ in ramp at (25.74, 25.69, -0.94).
# Placed Cl- in ramp at (40.56, 19.65, -9.96).
# 0: Placed Na+ in ramp at (-28.39, -10.84, -13.97).
# Placed Cl- in ramp at (-3.89, 36.52, -13.57).
# 0: Placed Na+ in ramp at (21.82, 29.52, -21.20).
# Placed Cl- in ramp at (-28.64, 10.57, -8.71).
# 0: Placed Na+ in ramp at (10.42, 6.28, 32.85).
# Placed Cl- in ramp at (-1.50, -43.48, 7.86).
# 0: Placed Na+ in ramp at (11.41, 5.36, 9.44).
# Placed Cl- in ramp at (-37.01, 31.33, -2.66).
# 0: Placed Na+ in ramp at (9.19, 46.39, 20.61).
# Placed Cl- in ramp at (-20.01, -33.88, 11.95).
# 0: Placed Na+ in ramp at (-11.47, 23.94, 37.33).
# Placed Cl- in ramp at (34.93, 25.48, 7.84).
# 0: Placed Na+ in ramp at (38.62, 22.67, -0.59).
# Placed Cl- in ramp at (-28.56, 33.79, -22.05).
# 0: Placed Na+ in ramp at (-9.20, -40.23, 20.90).
# Placed Cl- in ramp at (-34.16, -10.56, -10.38).
# 0: Placed Na+ in ramp at (-13.75, -26.75, 3.75).
# Placed Cl- in ramp at (0.57, 27.51, 23.48).
# 0: Placed Na+ in ramp at (-2.23, -42.79, -12.47).
# Placed Cl- in ramp at (17.38, 5.31, -36.32).
# 0: Placed Na+ in ramp at (-17.67, 26.08, -8.71).
# Placed Cl- in ramp at (-19.61, 21.76, 35.16).
# 0: Placed Na+ in ramp at (21.69, -18.36, -12.02).
# Placed Cl- in ramp at (-27.28, -15.87, 4.17).
# 0: Placed Na+ in ramp at (20.08, -1.83, -16.95).
# Placed Cl- in ramp at (10.95, -30.49, -30.49).
# 0: Placed Na+ in ramp at (-5.62, 25.55, -36.42).
# Placed Cl- in ramp at (37.02, -16.49, 9.39).
# 0: Placed Na+ in ramp at (-10.59, -6.66, 35.71).
# Placed Cl- in ramp at (-12.83, 8.55, -30.07).
# 0: Placed Na+ in ramp at (-22.58, -7.88, 26.17).
# Placed Cl- in ramp at (-29.37, 8.15, -6.95).
# 0: Placed Na+ in ramp at (13.13, 37.09, 20.63).
# Placed Cl- in ramp at (25.11, 39.46, -6.67).
# 0: Placed Na+ in ramp at (8.97, -27.43, 13.94).
# Placed Cl- in ramp at (-4.11, -44.77, -13.25).
# 0: Placed Na+ in ramp at (-39.05, -22.06, -21.87).
# Placed Cl- in ramp at (6.97, 29.68, -15.80).
# 0: Placed Na+ in ramp at (-30.46, -4.35, 31.00).
# Placed Cl- in ramp at (22.63, 2.91, 14.80).
# 0: Placed Na+ in ramp at (-6.72, 38.30, -19.23).
# Placed Cl- in ramp at (10.22, -0.81, 33.29).
# 0: Placed Na+ in ramp at (42.21, 3.28, 14.68).
# Placed Cl- in ramp at (-23.58, -7.13, -3.67).
# 0: Placed Na+ in ramp at (5.54, -18.48, 30.49).
# Placed Cl- in ramp at (-25.83, 2.52, -26.30).
# 0: Placed Na+ in ramp at (35.70, 8.70, -6.40).
# Placed Cl- in ramp at (13.26, -15.21, 28.10).
# 0: Placed Na+ in ramp at (-34.51, 10.87, -4.44).
# Placed Cl- in ramp at (35.31, -3.65, -10.31).
# 0: Placed Na+ in ramp at (-28.97, 23.91, -12.51).
# Placed Cl- in ramp at (-7.21, -41.60, -9.80).
# 0: Placed Na+ in ramp at (27.64, 3.81, 5.73).
# Placed Cl- in ramp at (-9.33, -2.46, 28.19).
# 0: Placed Na+ in ramp at (24.31, -24.25, 8.63).
# Placed Cl- in ramp at (-12.76, 15.35, 20.61).
# 0: Placed Na+ in ramp at (-22.48, -9.51, -19.19).
# Placed Cl- in ramp at (4.94, -1.65, 19.06).
# 0: Placed Na+ in ramp at (22.23, -2.23, 42.68).
# Placed Cl- in ramp at (16.48, -32.85, 7.57).
# 0: Placed Na+ in ramp at (-0.32, -19.03, 16.11).
# Placed Cl- in ramp at (-20.10, -1.18, 34.39).
# 0: Placed Na+ in ramp at (17.46, 6.85, 13.42).
# Placed Cl- in ramp at (-3.11, 0.95, 43.33).
# 0: Placed Na+ in ramp at (7.82, -32.60, -33.68).
# Placed Cl- in ramp at (-17.43, 0.48, 15.22).
# ```

# %% [markdown]
# ```tleap
# > saveamberparm ramp amber_o98.B99990002_ion.prmtop amber_o98.B99990002_ion.in$
# Checking Unit.
#
# Warning: The unperturbed charge of the unit (-12.000000) is not zero.
#
# Note: Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 908 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
#         res     total affected
#
#         CGLN    1
#         CILE    1
#         NMET    1
#         NTHR    1
#   )
#  (no restraints)
# ```

# %% [markdown]
# ## Trial 2
#
# NOT ENOUGH
#
# Neutralize protein system charge according to H++ output `.log`

# %% [markdown]
# ### III. Evaluate and Analyze the Protein Structure to be Imported into Amber

# %% [markdown]
# #### #7) Check protonation states*

# %% [markdown]
# Upload `amber_o98.B99990002.pdb` to http://newbiophysics.cs.vt.edu/H++/uploadpdb.php (account in Apple keychain) to calculate charge at pH 7.0
#
# ```out
# Isoelectric point = 5.21
# Total charge at pH 7.0 = -11
# ```

# %% [markdown]
# Download `0.15_80_10_pH7.0_amber_o98.B99990002.result.pdb` from H++ and visualize in VMD
#
# Seems like chain information is lost during H++ processing $\because$
# 1. VMD only shows 1 colour when coloured by chain
# 2. `.pdb` does NOT contain chain alphabet
#
# Make original `amber_o98.B99990002.pdb` neutral with Na$^+$ without touching His residues in the H++ output `.pdb` as stated by tutorial?

# %% [markdown]
# ### IV. Use LEaP to Build a Protein System in Explicit Solvent

# %% [markdown]
# a. Already set AMBERHOME in `.bashrc`

# %% [markdown]
# b. Start `tleap`
# ```sh
# wjoon21@puma:~/project/chen2023_possible_allosteric/B2$ tleap
# -I: Adding /home/t38guest/amber22/dat/leap/prep to search path.
# -I: Adding /home/t38guest/amber22/dat/leap/lib to search path.
# -I: Adding /home/t38guest/amber22/dat/leap/parm to search path.
# -I: Adding /home/t38guest/amber22/dat/leap/cmd to search path.
#
# Welcome to LEaP!
# (no leaprc in search path)
# ```

# %% [markdown]
# c. Load force fields
# ```tleap
# > source leaprc.protein.ff19SB
# ----- Source: /home/t38guest/amber22/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/t38guest/amber22/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/t38guest/amber22/dat/leap/lib/amino19.lib
# Loading library: /home/t38guest/amber22/dat/leap/lib/aminoct12.lib
# Loading library: /home/t38guest/amber22/dat/leap/lib/aminont12.lib
# ```
# ```tleap
# > source leaprc.water.opc
# ----- Source: /home/t38guest/amber22/dat/leap/cmd/leaprc.water.opc
# ----- Source of /home/t38guest/amber22/dat/leap/cmd/leaprc.water.opc done
# Loading library: /home/t38guest/amber22/dat/leap/lib/atomic_ions.lib
# Loading library: /home/t38guest/amber22/dat/leap/lib/solvents.lib
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/frcmod.opc
# Reading force field modification type file (frcmod)
# Reading title:
# Parameters for OPC water (JPCL, 2014, 5 (21), pp 3863-3871)
# Loading parameters: /home/t38guest/amber22/dat/leap/parm/frcmod.ionslm_126_opc
# Reading force field modification type file (frcmod)
# Reading title:
# Li/Merz ion parameters of atomic ions for the OPC water model (12-6 set)
# ```

# %% [markdown]
# d. Load `amber_o98.B99990002.pdb` into a UNIT called "ramp"
# ```tleap
# > ramp=loadpdb amber_o98.B99990002.pdb
# Loading PDB file: ./amber_o98.B99990002.pdb
#   total atoms in file: 2348
#   Leap added 2340 missing atoms according to residue templates:
#        2340 H / lone pairs
# ```
# NOT using output from H++ (`0.15_80_10_pH7.0_amber_o98.B99990002.result.pdb`) because
# 1. NO chain info

# %% [markdown]
# e. No disulfide bonds in native `.pdb`

# %% [markdown]
# f. Save a `.prmtop` and `.inpcrd` files of just the protein for analysis later.
# ```tleap
# > saveAmberParm ramp amber_o98_gas.prmtop amber_o98_gas.inpcrd
# Checking Unit.
#
# Warning: The unperturbed charge of the unit (-12.000000) is not zero.
#
# Note: Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 908 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
#         res     total affected
#
#         CGLN    1
#         CILE    1
#         NMET    1
#         NTHR    1
#   )
#  (no restraints)
# ```
# `tleap` reports the charge is -12.0 instead of -11.0 (H++)?

# %% [markdown]
# g. Add neutralizing charges
# ```tleap
# > addIons ramp Na+ 11
# Adding 11 counter ions to "ramp" using 1A grid
# Grid extends from solute vdw + 3.36  to  9.34
# Resolution:      1.00 Angstrom.
#  (no solvent present)
# Calculating grid charges
# Placed Na+ in ramp at (-19.47, 66.10, 118.47).
# Placed Na+ in ramp at (4.53, 83.10, 145.47).
# Placed Na+ in ramp at (13.53, 83.10, 137.47).
# Placed Na+ in ramp at (-6.47, 52.10, 99.47).
# Placed Na+ in ramp at (20.53, 82.10, 97.47).
# Placed Na+ in ramp at (-3.47, 74.10, 145.47).
# Placed Na+ in ramp at (29.53, 83.10, 128.47).
# Placed Na+ in ramp at (-18.47, 59.10, 121.47).
# Placed Na+ in ramp at (-2.47, 88.10, 107.47).
# Placed Na+ in ramp at (-8.47, 56.10, 108.47).
# Placed Na+ in ramp at (6.53, 75.10, 143.47).
#
# Done adding ions.
# ```

# %% [markdown]
# h. Add a truncated octahedron box of OPC water
# ```tleap
# > solvateOct ramp OPCBOX 10.0
# Scaling up box by a factor of 1.389659 to meet diagonal cut criterion
#   Solute vdw bounding box:              71.259 63.638 54.379
#   Total bounding box for atom centers:  99.052 99.052 99.052
#       (box expansion for 'iso' is  30.6%)
#   Solvent unit box:                     18.865 18.478 19.006
#   Volume: 500787.116 A^3 (oct)
#   Total mass 269464.258 amu,  Density 0.894 g/cc
#   Added 13088 residues.
# ```

# %% [markdown]
# i. Add a buffer ions with random positions.
#
# Add a 150 mM NaCl salt buffer that is present in cells, which will require adding Na$^+$ and Cl$^-$ ions, based on the volume of the box.
#
# https://ambermd.org/tutorials/basic/tutorial8/index.php
#
# NOTE: the salt (ion) concentration in the source organism (tobacco _plant_) may NOT be the same

# %%
volumeOctBoxAngstrom = 500787.116
volumeOctBoxAngstrom
# Out:
# 500787.116

# %%
volumeOctBoxLiter = volumeOctBoxAngstrom * 1/(10**10)**3 * (10**2)**3/1 * 1/1 * 1/10**3
volumeOctBoxLiter
# Out:
# 5.00787116e-22

# %%
numberClperLiter = 150/1 * 1/10**3 * (6.022*10**23)/1
numberClperLiter
# Out:
# 9.033e+22

# %%
numberClOctBox = volumeOctBoxLiter * numberClperLiter
numberClOctBox
# Out:
# 45.23610018828

# %% [markdown]
# Round to nearest whole number (i.e., 45 Na$^+$ and 45 Cl$^-$ ions) and add to `ramp`
# ```tleap
# > addIonsRand ramp Na+ 45 Cl- 45
# Adding 90 counter ions to "ramp". 12998 solvent molecules will remain.
# 0: Placed Na+ in ramp at (-13.52, 34.81, -36.86).
# Placed Cl- in ramp at (-13.58, -33.60, 5.70).
# 0: Placed Na+ in ramp at (-24.43, -27.31, 16.22).
# Placed Cl- in ramp at (-26.97, -18.56, 3.86).
# 0: Placed Na+ in ramp at (-35.29, -11.31, -22.88).
# Placed Cl- in ramp at (39.84, -7.47, 7.87).
# 0: Placed Na+ in ramp at (-3.23, 24.52, -22.78).
# Placed Cl- in ramp at (-22.48, -40.09, 6.49).
# 0: Placed Na+ in ramp at (38.20, 15.62, -17.37).
# Placed Cl- in ramp at (11.31, 13.88, 5.25).
# 0: Placed Na+ in ramp at (2.98, -5.92, -44.34).
# Placed Cl- in ramp at (-15.96, -9.71, -32.40).
# 0: Placed Na+ in ramp at (-38.84, 29.09, -12.23).
# Placed Cl- in ramp at (-27.14, -5.80, 1.38).
# 0: Placed Na+ in ramp at (25.85, 13.86, -25.92).
# Placed Cl- in ramp at (-21.43, 13.96, 43.38).
# 0: Placed Na+ in ramp at (-1.87, 23.51, -11.48).
# Placed Cl- in ramp at (38.46, -28.31, -15.56).
# 0: Placed Na+ in ramp at (-3.04, 1.23, 39.33).
# Placed Cl- in ramp at (-31.08, 18.03, -29.39).
# 0: Placed Na+ in ramp at (22.55, 9.33, 3.32).
# Placed Cl- in ramp at (-7.79, -6.90, -33.03).
# 0: Placed Na+ in ramp at (-17.11, -18.96, 23.04).
# Placed Cl- in ramp at (14.01, -29.63, -1.56).
# 0: Placed Na+ in ramp at (18.85, 4.83, -38.73).
# Placed Cl- in ramp at (4.48, 4.00, 30.29).
# 0: Placed Na+ in ramp at (20.50, -0.56, 26.47).
# Placed Cl- in ramp at (-3.82, 34.58, -28.93).
# 0: Placed Na+ in ramp at (27.26, 24.95, 10.89).
# Placed Cl- in ramp at (3.84, -19.83, 28.64).
# 0: Placed Na+ in ramp at (-17.86, 1.74, 8.93).
# Placed Cl- in ramp at (-17.62, 16.09, 27.29).
# 0: Placed Na+ in ramp at (2.32, -1.62, 34.02).
# Placed Cl- in ramp at (-0.62, 23.35, -0.19).
# 0: Placed Na+ in ramp at (-28.51, 0.27, -20.11).
# Placed Cl- in ramp at (0.77, 36.43, 2.71).
# 0: Placed Na+ in ramp at (7.31, 12.01, -30.54).
# Placed Cl- in ramp at (-31.29, -8.17, -4.41).
# 0: Placed Na+ in ramp at (6.92, -34.27, -30.26).
# Placed Cl- in ramp at (-9.55, -9.72, -22.08).
# 0: Placed Na+ in ramp at (26.98, 16.37, 27.26).
# Placed Cl- in ramp at (1.35, 23.06, 35.17).
# 0: Placed Na+ in ramp at (31.65, 7.52, -32.54).
# Placed Cl- in ramp at (10.41, 22.73, 5.18).
# 0: Placed Na+ in ramp at (-10.12, 18.03, -43.61).
# Placed Cl- in ramp at (-41.47, 4.78, -28.02).
# 0: Placed Na+ in ramp at (-3.68, 18.08, 1.23).
# Placed Cl- in ramp at (-14.58, -10.54, 23.13).
# 0: Placed Na+ in ramp at (28.55, -14.53, 6.66).
# Placed Cl- in ramp at (-31.93, -21.98, 3.05).
# 0: Placed Na+ in ramp at (-23.51, 15.54, 1.59).
# Placed Cl- in ramp at (-22.75, 7.57, -10.87).
# 0: Placed Na+ in ramp at (28.87, -22.98, 7.87).
# Placed Cl- in ramp at (23.17, -25.36, -25.63).
# 0: Placed Na+ in ramp at (33.92, 5.21, -19.14).
# Placed Cl- in ramp at (-7.97, 29.30, -9.33).
# 0: Placed Na+ in ramp at (20.90, -0.01, 29.14).
# Placed Cl- in ramp at (42.05, -4.06, 27.33).
# 0: Placed Na+ in ramp at (-23.02, -4.61, 26.78).
# Placed Cl- in ramp at (24.28, 41.40, 5.29).
# 0: Placed Na+ in ramp at (-31.83, -28.21, -11.83).
# Placed Cl- in ramp at (26.89, -1.58, 32.19).
# 0: Placed Na+ in ramp at (7.28, -23.83, 40.32).
# Placed Cl- in ramp at (-0.52, -16.29, 33.34).
# 0: Placed Na+ in ramp at (7.32, 3.25, 21.27).
# Placed Cl- in ramp at (-16.83, 13.94, -33.98).
# 0: Placed Na+ in ramp at (-21.13, -21.87, 2.96).
# Placed Cl- in ramp at (9.90, 15.53, -28.48).
# 0: Placed Na+ in ramp at (-21.12, 11.63, -44.96).
# Placed Cl- in ramp at (-7.55, -23.55, -24.77).
# 0: Placed Na+ in ramp at (-10.35, -6.62, 35.76).
# Placed Cl- in ramp at (-14.84, 21.19, -39.92).
# 0: Placed Na+ in ramp at (9.26, -37.15, -23.75).
# Placed Cl- in ramp at (-23.33, -27.67, 13.72).
# 0: Placed Na+ in ramp at (-10.76, -21.83, -27.23).
# Placed Cl- in ramp at (25.17, 39.78, 11.85).
# 0: Placed Na+ in ramp at (-37.61, 8.98, -21.57).
# Placed Cl- in ramp at (30.35, -15.72, -23.24).
# 0: Placed Na+ in ramp at (10.18, 41.58, -5.71).
# Placed Cl- in ramp at (-8.88, 14.38, 34.44).
# 0: Placed Na+ in ramp at (-18.87, -6.08, -35.45).
# Placed Cl- in ramp at (-13.93, -16.32, -37.37).
# 0: Placed Na+ in ramp at (-32.54, 21.82, 3.64).
# Placed Cl- in ramp at (19.32, 36.32, 4.86).
# 0: Placed Na+ in ramp at (3.87, -2.67, -49.49).
# Placed Cl- in ramp at (34.08, 15.44, 9.20).
# 0: Placed Na+ in ramp at (37.01, 4.27, 30.57).
# Placed Cl- in ramp at (-32.66, -14.12, -30.39).
# 0: Placed Na+ in ramp at (-23.55, -6.98, 18.81).
# Placed Cl- in ramp at (14.70, 31.40, 3.85).
# ```

# %% [markdown]
# j. Save the `.prmtop` and `.inpcrd` files
# ```tleap
# > saveamberparm ramp amber_o98_ion.prmtop amber_o98_ion.inpcrd
# Checking Unit.
#
# Warning: The unperturbed charge of the unit (-1.000000) is not zero.
#
# Note: Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 908 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
#         res     total affected
#
#         CGLN    1
#         CILE    1
#         NMET    1
#         NTHR    1
#   )
#  (no restraints)
# ```
# Still has WARNING...

# %% [markdown]
# ## Trial 3
# FAIL
#
# Get parameters (`parm7`) and input coordinates (`rst7`) with H++ output `pdb` ($\because$ maybe this has coordinate shifts based on pH?)

# %% [markdown]
# ### IV. Use LEaP to Build a Protein System in Explicit Solvent

# %% [markdown]
# d. Load `0.15_80_10_pH7.0_amber_o98.B99990002.pdb` into a UNIT called "ramp"
# ```tleap
# > ramp=loadpdb 0.15_80_10_pH7.0_amber_o98.B99990002.result.pdb
# Loading PDB file: ./0.15_80_10_pH7.0_amber_o98.B99990002.result.pdb
# Created a new atom named: HD1 within residue: .R<HIE 84>
# Created a new atom named: HD1 within residue: .R<HIE 135>
# Created a new atom named: HD1 within residue: .R<HIE 268>
#   total atoms in file: 4689
#   Leap added 2 missing atoms according to residue templates:
#        2 H / lone pairs
#   The file contained 3 atoms not in residue templates
# ```

# %% [markdown]
# f. Save a `parm7` (`.prmtop`) and `rst7` (`.inpcrd`) files of just the protein for analysis later.
# ```tleap
# > saveamberparm ramp parm7 rst7
# Checking Unit.
#
# Warning: The unperturbed charge of the unit (-12.000000) is not zero.
# FATAL:  Atom .R<HIE 84>.A<HD1 18> does not have a type.
# FATAL:  Atom .R<HIE 135>.A<HD1 18> does not have a type.
# FATAL:  Atom .R<HIE 268>.A<HD1 18> does not have a type.
#
# Error: Failed to generate parameters
#
# Warning: Parameter file was not saved.
# ```
# `does not have a type`??
#
# Need to manually change residue name in the `pdb` like the tutorial?

# %% [markdown]
# ## Trial 4
# Neutralize protein charge based on output from `saveamberparm` warning for only protein (before buffer)

# %% [markdown]
# ### IV. Use LEaP to Build a Protein System in Explicit Solvent

# %% [markdown]
# d. Load `amber_o98.B99990002.pdb` into a UNIT called "ramp"
# ```tleap
# > ramp=loadpdb amber_o98.B99990002.pdb
# Loading PDB file: ./amber_o98.B99990002.pdb
#   total atoms in file: 2348
#   Leap added 2340 missing atoms according to residue templates:
#        2340 H / lone pairs
# ```
# NOT using output from H++ (`0.15_80_10_pH7.0_amber_o98.B99990002.result.pdb`) because
# 1. NO chain info
# 2. `does not have a type` atoms

# %% [markdown]
# f. Save a `parm7` (`.prmtop`) and `rst7` (`.inpcrd`) files of just the protein for analysis later.
# ```tleap
# > saveamberparm ramp amber_o98_gas.parm7 amber_o98_gas.rst
# Checking Unit.
#
# Warning: The unperturbed charge of the unit (-12.000000) is not zero.
#
# Note: Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 908 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
#         res     total affected
#
#         CGLN    1
#         CILE    1
#         NMET    1
#         NTHR    1
#   )
#  (no restraints)
# ```
# Why did `tleap` QUIT on its own after this? RESTART with same commands EXCEPT this intermediate protein-only saves

# %% [markdown]
# g. Add neutralizing charges according to `Warning: The unperturbed charge of the unit (-12.000000) is not zero.`
# ```tleap
# > addIons ramp Na+ 12
# Adding 12 counter ions to "ramp" using 1A grid
# Grid extends from solute vdw + 3.45  to  9.43
# Resolution:      1.00 Angstrom.
#  (no solvent present)
# Calculating grid charges
# Placed Na+ in ramp at (-19.56, 63.01, 118.37).
# Placed Na+ in ramp at (6.44, 75.01, 143.37).
# Placed Na+ in ramp at (13.44, 84.01, 137.37).
# Placed Na+ in ramp at (-8.56, 52.01, 100.37).
# Placed Na+ in ramp at (20.44, 82.01, 97.37).
# Placed Na+ in ramp at (29.44, 82.01, 129.37).
# Placed Na+ in ramp at (3.44, 83.01, 146.37).
# Placed Na+ in ramp at (-12.56, 60.01, 111.37).
# Placed Na+ in ramp at (-1.56, 89.01, 108.37).
# Placed Na+ in ramp at (17.44, 54.01, 121.37).
# Placed Na+ in ramp at (-3.56, 72.01, 145.37).
# Placed Na+ in ramp at (19.44, 73.01, 103.37).
#
# Done adding ions.
# ```

# %% [markdown]
# h. Add a truncated octahedron box of OPC water
# ```tleap
# > solvateOct ramp OPCBOX 10.0
# Scaling up box by a factor of 1.388100 to meet diagonal cut criterion
#   Solute vdw bounding box:              71.217 63.660 54.425
#   Total bounding box for atom centers:  98.979 98.979 98.979
#       (box expansion for 'iso' is  30.4%)
#   Solvent unit box:                     18.865 18.478 19.006
#   Volume: 499681.485 A^3 (oct)
#   Total mass 268712.560 amu,  Density 0.893 g/cc
#   Added 13045 residues.
# ```

# %% [markdown]
# i. Add a buffer ions with random positions.
#
# Add a 150 mM NaCl salt buffer that is present in cells, which will require adding Na+
# and Cl−
#
# ions, based on the volume of the box.
#
# https://ambermd.org/tutorials/basic/tutorial8/index.php

# %%
volumeOctBoxAngstrom = 499681.485
volumeOctBoxAngstrom
# Out:
# 499681.485

# %%
volumeOctBoxLiter = volumeOctBoxAngstrom * 1/(10**10)**3 * (10**2)**3/1 * 1/1 * 1/10**3
volumeOctBoxLiter
# Out:
# 4.99681485e-22

# %%
numberClperLiter = 150/1 * 1/10**3 * (6.022*10**23)/1
numberClperLiter
# Out:
# 9.033e+22

# %%
numberClOctBox = volumeOctBoxLiter * numberClperLiter
numberClOctBox
# Out:
# 45.13622854005

# %% [markdown]
# Round to nearest whole number (i.e., 45 Na$^+$ and Cl$^-$ ions) and add to `ramp`
# ```tleap
# > addIonsRand ramp Na+ 45 Cl- 45
# Adding 90 counter ions to "ramp". 12955 solvent molecules will remain.
# 0: Placed Na+ in ramp at (19.16, 11.71, 3.16).
# Placed Cl- in ramp at (-27.75, 19.63, -28.16).
# 0: Placed Na+ in ramp at (24.56, 29.44, -2.71).
# Placed Cl- in ramp at (-2.29, -40.86, 12.40).
# 0: Placed Na+ in ramp at (9.36, 5.43, -36.46).
# Placed Cl- in ramp at (6.33, -35.71, -1.27).
# 0: Placed Na+ in ramp at (36.56, -15.37, -5.30).
# Placed Cl- in ramp at (-14.82, -24.54, -2.41).
# 0: Placed Na+ in ramp at (-40.87, 17.63, 18.08).
# Placed Cl- in ramp at (37.07, -10.72, 10.25).
# 0: Placed Na+ in ramp at (-37.93, -8.13, -9.12).
# Placed Cl- in ramp at (12.27, 48.75, 9.20).
# 0: Placed Na+ in ramp at (31.37, 17.67, 18.33).
# Placed Cl- in ramp at (13.08, 26.04, -21.12).
# 0: Placed Na+ in ramp at (8.24, -34.22, 27.42).
# Placed Cl- in ramp at (-17.31, 11.37, -20.37).
# 0: Placed Na+ in ramp at (14.45, 23.21, 4.86).
# Placed Cl- in ramp at (-15.74, 16.06, -5.56).
# 0: Placed Na+ in ramp at (-1.00, 16.74, -28.50).
# Placed Cl- in ramp at (-13.05, -17.64, 18.91).
# 0: Placed Na+ in ramp at (30.84, -33.04, -22.85).
# Placed Cl- in ramp at (5.10, -8.61, 32.98).
# 0: Placed Na+ in ramp at (2.06, 29.68, -27.41).
# Placed Cl- in ramp at (35.05, -30.67, -14.67).
# 0: Placed Na+ in ramp at (40.32, -19.47, 5.48).
# Placed Cl- in ramp at (3.57, -30.56, 30.53).
# 0: Placed Na+ in ramp at (-6.75, 10.93, 28.36).
# Placed Cl- in ramp at (37.71, -1.35, 19.38).
# 0: Placed Na+ in ramp at (-41.64, 14.26, 7.76).
# Placed Cl- in ramp at (-22.80, 28.70, -17.45).
# 0: Placed Na+ in ramp at (-22.87, -30.75, -13.25).
# Placed Cl- in ramp at (42.41, 5.87, 22.84).
# 0: Placed Na+ in ramp at (-20.12, 28.65, -24.84).
# Placed Cl- in ramp at (39.71, -5.72, -26.27).
# 0: Placed Na+ in ramp at (-15.54, 11.27, -7.84).
# Placed Cl- in ramp at (-23.54, -2.55, 25.20).
# 0: Placed Na+ in ramp at (-4.09, 8.26, 37.41).
# Placed Cl- in ramp at (20.01, 15.66, 20.93).
# 0: Placed Na+ in ramp at (3.95, 14.87, 14.70).
# Placed Cl- in ramp at (31.11, 34.51, 9.23).
# 0: Placed Na+ in ramp at (31.48, 14.95, 22.49).
# Placed Cl- in ramp at (-18.95, 7.78, 14.53).
# 0: Placed Na+ in ramp at (19.71, 11.91, -17.99).
# Placed Cl- in ramp at (-36.03, 20.00, 15.99).
# 0: Placed Na+ in ramp at (35.02, 20.53, 25.34).
# Placed Cl- in ramp at (15.30, 19.26, -25.38).
# 0: Placed Na+ in ramp at (-22.66, 18.24, -19.05).
# Placed Cl- in ramp at (-10.59, -37.07, -23.08).
# 0: Placed Na+ in ramp at (-8.61, -2.89, 39.97).
# Placed Cl- in ramp at (11.93, -14.26, 46.42).
# 0: Placed Na+ in ramp at (40.50, -3.38, -22.97).
# Placed Cl- in ramp at (-14.32, -4.72, 34.34).
# 0: Placed Na+ in ramp at (-13.35, -40.70, 5.84).
# Placed Cl- in ramp at (-23.92, 23.64, 24.75).
# 0: Placed Na+ in ramp at (12.90, -34.81, 31.60).
# Placed Cl- in ramp at (-19.76, 5.12, 41.31).
# 0: Placed Na+ in ramp at (3.06, -33.02, -18.17).
# Placed Cl- in ramp at (10.83, -17.24, -36.48).
# 0: Placed Na+ in ramp at (-22.64, 12.38, 35.79).
# Placed Cl- in ramp at (29.03, 13.45, 26.50).
# 0: Placed Na+ in ramp at (-15.70, -31.83, 12.53).
# Placed Cl- in ramp at (30.36, 0.72, -24.27).
# 0: Placed Na+ in ramp at (-29.33, -7.30, -35.89).
# Placed Cl- in ramp at (5.30, -34.63, -18.10).
# 0: Placed Na+ in ramp at (-22.26, 15.37, 12.88).
# Placed Cl- in ramp at (32.07, -13.84, 31.80).
# 0: Placed Na+ in ramp at (-3.03, -0.92, 49.73).
# Placed Cl- in ramp at (4.78, 13.27, -40.61).
# 0: Placed Na+ in ramp at (10.46, -0.77, 33.34).
# Placed Cl- in ramp at (5.01, 16.82, -8.48).
# 0: Placed Na+ in ramp at (21.87, -28.33, -0.53).
# Placed Cl- in ramp at (-23.55, 36.35, 5.30).
# 0: Placed Na+ in ramp at (-20.21, -24.18, -17.33).
# Placed Cl- in ramp at (-34.79, -23.05, -11.48).
# 0: Placed Na+ in ramp at (-10.30, -25.65, 9.49).
# Placed Cl- in ramp at (-20.83, -14.37, 19.74).
# 0: Placed Na+ in ramp at (38.58, -23.65, -22.65).
# Placed Cl- in ramp at (-19.24, -0.68, 40.37).
# 0: Placed Na+ in ramp at (17.33, 14.66, -9.85).
# Placed Cl- in ramp at (12.99, -23.47, 27.58).
# 0: Placed Na+ in ramp at (21.01, 20.61, -7.19).
# Placed Cl- in ramp at (-26.60, -28.86, -16.11).
# 0: Placed Na+ in ramp at (18.62, 25.99, -6.61).
# Placed Cl- in ramp at (31.46, 0.29, -28.21).
# 0: Placed Na+ in ramp at (-28.31, 26.18, 28.09).
# Placed Cl- in ramp at (-24.81, -31.87, -18.86).
# 0: Placed Na+ in ramp at (5.39, 17.13, -2.45).
# Placed Cl- in ramp at (-7.74, -22.51, -32.54).
# 0: Placed Na+ in ramp at (-26.04, 10.45, -28.22).
# Placed Cl- in ramp at (-36.99, 28.44, 6.80).
# ```

# %% [markdown]
# j. Save the `.parm7` and `.rst` files
# ```tleap
# > saveamberparm ramp amber_o98_ion.parm7 amber_o98_ion.rst
# Checking Unit.
#
# Note: Ignoring the warnings from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 908 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
#         res     total affected
#
#         CGLN    1
#         CILE    1
#         NMET    1
#         NTHR    1
#   )
#  (no restraints)
# ```

# %% [markdown]
# ## Trial 5
# Run `tleap.in` script to ouput `parm7` and `rst7` files

# %% [markdown]
# ```tleap
# > source tleap.in
# ...
# ```
# SAME output as running individual `tleap` commands

# %% [markdown]
# Convert `parm7` and `rst7` files into a `pdb` file with:
# ```in
# #cpptraj_pdb.in
# trajin amber_o98_ion.rst7
# trajout amber_o98_wions_water.pdb PDB
# run
# ```

# %%
# !cpptraj -p amber_o98_ion.parm7 -i cpptraj_pdb.in > cpptraj_pdb.out

# %% [markdown]
# Output: `cpptraj_out.pdb` and `amber_o98_wions_water.pdb`

# %% [markdown]
# ## Trial 6
# Solvate the pre-minimized protein-only system from GROMACS (`min_gromacs_o98.pdb`)

# %%
volumeOctBoxAngstrom = 497534.510
volumeOctBoxLiter = volumeOctBoxAngstrom * 1/(10**10)**3 * (10**2)**3/1 * 1/1 * 1/10**3
numberClperLiter = 150/1 * 1/10**3 * (6.022*10**23)/1
numberClOctBox = volumeOctBoxLiter * numberClperLiter
numberClOctBox
# Out:
# 44.942292288299996

# %% [markdown]
# FAIL in next step
#
# REDUNDANT

# %% [markdown]
# # USE TRIAL 5 OUTPUT FOR NEXT STEP (`03_relaxation_explicit_water.ipynb`)
# Before 2024/06/17

# %% [markdown]
# ## Trial 7
# Carried out in cluster (`studenT38@hen`) with AMBER20 (latest available version)

# %% [markdown]
# Load AMBER20
# ```sh
# module load amber/20.13/21.12
# ```

# %% [markdown]
# (Re-)Convert `o98.B99990002.pdb` (MODELLER output)
# ```sh
# pdb4amber o98.B99990002.pdb
# ```

# %% [markdown]
# Truncated octahedron (10.0 Angstroms) $\rightarrow$ cubic (12.5 Angstroms)
#
# To match `chen2023`

# %% [markdown]
# `tleap.in`
# ```in
# source leaprc.protein.ff19SB
# source leaprc.water.opc
# ramp=loadpdb amber_o98.B99990002.pdb
# saveamberparm ramp amber_o98_gas.parm7 amber_o98_gas.rst7
# addIons ramp Na+ 12
# ...
# ```

# %% [markdown]
# To add ions to solvent
# ```
# > solvateBox ramp OPCBOX 12.5
#   Solute vdw bounding box:              67.965 64.951 61.522
#   Total bounding box for atom centers:  92.965 89.951 86.522
#   Solvent unit box:                     18.865 18.478 19.006
#   Total vdw box size:                   95.958 93.209 89.522 angstroms.
#   Volume: 800696.376 A^3
#   Total mass 404841.456 amu,  Density 0.840 g/cc
#   Added 20601 residues.
# ```

# %%
volumeBoxAngstrom = 800696.376
volumeBoxLiter = volumeBoxAngstrom * 1/(10**10)**3 * (10**2)**3/1 * 1/1 * 1/10**3
numberClLiter = 150/1 * 1/10**3 * (6.022*10**23)/1
numberClBox = volumeBoxLiter * numberClLiter
numberClBox
# Out:
# 72.32690364408

# %% [markdown]
# `tleap.in` cont.
# ```in
# ...
# addIonsRand ramp Na+ 72 Cl- 72
# saveamberparm ramp amber_o98_cubic_ion.parm7 amber_o98_cubic_ion.rst7
# ```
